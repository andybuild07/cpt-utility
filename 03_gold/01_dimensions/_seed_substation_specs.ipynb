# %%
# %sql
-- capacity and voltage source
CREATE OR REPLACE TEMP VIEW tv_substation_specs AS
SELECT * FROM (VALUES
    ('Clovelly', 80.0, 11.66),
    ('Sun Valley', 80.0, 11.66),
    ('Muizenberg', 80.0, 11.66),
    ('Steenberg', 100.0, 11.66),
    ('Bisschop', 80.0, 11.66),
    ('Retreat', 100.0, 11.66),
    ('Constantia', 60.0, 11.66),
    ('Sea Point', 60.0, 11.66),
    ('Piers Road', 100.0, 11.66),
    ('Pelican Park', 80.0, 11.66),
    ('Grassy Park', 100.0, 11.66),
    ('Rosmead', 100.0, 11.66),
    ('Tamboerskloof', 80.0, 11.66),
    ('Mouille Point', 100.0, 11.66),
    ('Green Point', 60.0, 11.66),
    ('Roggebaai', 100.0, 11.66),
    ('Foreshore', 100.0, 11.66),
    ('Gateway', 40.0, 11.66),
    ('Constitution Street', 80.0, 11.66),
    ('Woodstock', 80.0, 11.66),
    ('City North', 120.0, 11.66),
    ('Loch Road', 100.0, 11.66),
    ('Observatory', 100.0, 11.66),
    ('Lansdowne', 80.0, 11.66),
    ('Newfields', 100.0, 11.66),
    ('Weltevreden', 80.0, 11.66),
    ('Spine Road', 80.0, 11.66),
    ('Eastridge', 80.0, 11.66),
    ('Eisleben Drive', 80.0, 11.66),
    ('Mitchells Plain', 80.0, 11.66),
    ('Gugulethu', 120.0, 11.66),
    ('Newlands', 120.0, 11.66),
    ('Vanguard', 100.0, 11.66),
    ('Bofors', 100.0, 11.66),
    ('Jan Smuts', 80.0, 11.66),
    ('Bonteheuwel', 80.0, 11.66),
    ('Broad Road', 80.0, 11.66),
    ('Epping', 120.0, 11.66),
    ('Maitland', 100.0, 11.66),
    ('Kensington', 80.0, 11.66),
    ('Montague Gardens', 60.0, 11.66),
    ('Century City', 100.0, 11.66),
    ('Milnerton', 80.0, 11.66),
    ('N1', 80.0, 11.50),
    ('Richmond Estate', 100.0, 11.50),
    ('Elsies River', 80.0, 11.50),
    ('Tiervlei', 80.0, 11.50),
    ('Parow South', 80.0, 11.50),
    ('Tygerberg Hospital', 80.0, 11.50),
    ('Bellville South', 100.0, 11.50),
    ('Westhof', 40.0, 11.50),
    ('Boston', 60.0, 11.50),
    ('Doordekraal', 60.0, 11.50),
    ('Oakdale', 60.0, 11.50),
    ('Triangle', 100.0, 11.50),
    ('Sacks Circle', 100.0, 11.50),
    ('Langverwacht', 80.0, 11.50),
    ('Morgen Gronde', 100.0, 11.50),
    ('Brackenfell', 80.0, 11.50),
    ('Eversdal', 100.0, 11.50),
    ('Langeberg', 80.0, 11.50),
    ('Marais', 40.0, 11.50),
    ('Kraaifontein', 100.0, 11.50),
    ('Durbanville', 80.0, 11.50),
    ('Uitkamp', 40.0, 11.50),
    ('Helderberg', 80.0, 11.50),
    ('Somerset West', 80.0, 11.50),
    ('Strand', 120.0, 11.50),
    ('Gordons Bay', 40.0, 11.50),
    ('Depot', 40.0, 11.50),
    ('William Gourley', 80.0, 11.50),
    ('John Dreyer', 30.0, 11.50),
    ('Gardenia', 20.0, 11.50),
    ('Sampson', 20.0, 11.50),
    ('Grosvenor', 40.0, 11.50),
    ('Midlands', 10.0, 11.50)
) AS t(substation_name, capacity, voltage);
